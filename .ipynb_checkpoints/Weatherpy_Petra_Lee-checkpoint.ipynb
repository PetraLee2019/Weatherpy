# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "/data/output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aykhal
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | husavik
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | turukhansk
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | flinders
# Processing Record 20 of Set 1 | kavaratti
# Processing Record 21 of Set 1 | sacramento
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | balaipungut
# Processing Record 24 of Set 1 | ust-nera
# Processing Record 25 of Set 1 | rio grande
# Processing Record 26 of Set 1 | hualmay
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | beringovskiy
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | bambous virieux
# Processing Record 31 of Set 1 | sept-iles
# Processing Record 32 of Set 1 | esperance
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | broome
# Processing Record 38 of Set 1 | padang
# Processing Record 39 of Set 1 | ust-tsilma
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 1 | tateyama
# Processing Record 43 of Set 1 | kutno
# Processing Record 44 of Set 1 | sao filipe
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | kattivakkam
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | cabedelo
# Processing Record 50 of Set 1 | san rafael
# Processing Record 0 of Set 2 | atambua
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | karpathos
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | honiara
# Processing Record 7 of Set 2 | shimoda
# Processing Record 8 of Set 2 | tuatapere
# Processing Record 9 of Set 2 | kalmunai
# Processing Record 10 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | muroto
# Processing Record 13 of Set 2 | honningsvag
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | siguiri
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | srandakan
# Processing Record 19 of Set 2 | bambanglipuro
# Processing Record 20 of Set 2 | mercedes
# Processing Record 21 of Set 2 | carballo
# Processing Record 22 of Set 2 | fiche
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | fuxin
# Processing Record 26 of Set 2 | rosarito
# Processing Record 27 of Set 2 | mazagao
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | xining
# Processing Record 31 of Set 2 | severnoye
# Processing Record 32 of Set 2 | camocim
# Processing Record 33 of Set 2 | yaring
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | boa esperanca
# Processing Record 36 of Set 2 | tupiza
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | palmas
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | mae hong son
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | batanovci
# Processing Record 44 of Set 2 | hamilton
# Processing Record 45 of Set 2 | lubango
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | beloha
# Processing Record 48 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 49 of Set 2 | pelym
# Processing Record 0 of Set 3 | rio rancho
# Processing Record 1 of Set 3 | henties bay
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | belyy yar
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | goba
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | los llanos de aridane
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | acapulco
# Processing Record 15 of Set 3 | cururupu
# Processing Record 16 of Set 3 | durango
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | abrau-dyurso
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | botwood
# Processing Record 21 of Set 3 | polyarnyy
# Processing Record 22 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | qostanay
# Processing Record 25 of Set 3 | codrington
# Processing Record 26 of Set 3 | farafangana
# Processing Record 27 of Set 3 | west bay
# Processing Record 28 of Set 3 | port macquarie
# Processing Record 29 of Set 3 | korla
# City not found. Skipping...
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | kollumerland
# City not found. Skipping...
# Processing Record 33 of Set 3 | alamogordo
# Processing Record 34 of Set 3 | kitimat
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | quatre cocos
# Processing Record 37 of Set 3 | fairbanks
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | kirakira
# Processing Record 40 of Set 3 | manokwari
# Processing Record 41 of Set 3 | kavarna
# Processing Record 42 of Set 3 | narsaq
# Processing Record 43 of Set 3 | belen
# Processing Record 44 of Set 3 | provideniya
# Processing Record 45 of Set 3 | hilo
# Processing Record 46 of Set 3 | gornopravdinsk
# Processing Record 47 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 48 of Set 3 | beberibe
# Processing Record 49 of Set 3 | burnie
# Processing Record 0 of Set 4 | dunedin
# Processing Record 1 of Set 4 | ambilobe
# Processing Record 2 of Set 4 | santa fe
# Processing Record 3 of Set 4 | teya
# Processing Record 4 of Set 4 | tangwani
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | melbourne
# Processing Record 7 of Set 4 | coxim
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | ilebo
# Processing Record 13 of Set 4 | upernavik
# Processing Record 14 of Set 4 | osinki
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | tiarei
# Processing Record 21 of Set 4 | malatya
# Processing Record 22 of Set 4 | hovd
# Processing Record 23 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 4 | talnakh
# Processing Record 25 of Set 4 | san isidro
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | kralendijk
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | sambava
# Processing Record 30 of Set 4 | chistogorskiy
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | namibe
# Processing Record 34 of Set 4 | mount isa
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | whitecourt
# Processing Record 37 of Set 4 | kiama
# Processing Record 38 of Set 4 | isabela
# Processing Record 39 of Set 4 | komsomolskiy
# Processing Record 40 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 42 of Set 4 | ocampo
# Processing Record 43 of Set 4 | batemans bay
# Processing Record 44 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 4 | banda aceh
# Processing Record 46 of Set 4 | jalu
# Processing Record 47 of Set 4 | marsa matruh
# Processing Record 48 of Set 4 | bangolo
# Processing Record 49 of Set 4 | tonstad
# Processing Record 0 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 5 | marzuq
# Processing Record 2 of Set 5 | manuk mangkaw
# Processing Record 3 of Set 5 | namatanai
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | zyryanka
# Processing Record 6 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 5 | salym
# Processing Record 8 of Set 5 | aklavik
# Processing Record 9 of Set 5 | kytmanovo
# Processing Record 10 of Set 5 | obihiro
# Processing Record 11 of Set 5 | lazaro cardenas
# Processing Record 12 of Set 5 | karanganyar
# Processing Record 13 of Set 5 | candido mendes
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | angul
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | batagay-alyta
# Processing Record 18 of Set 5 | fort nelson
# Processing Record 19 of Set 5 | saskylakh
# Processing Record 20 of Set 5 | tilichiki
# Processing Record 21 of Set 5 | saint anthony
# Processing Record 22 of Set 5 | shelburne
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | umm lajj
# Processing Record 25 of Set 5 | lufilufi
# Processing Record 26 of Set 5 | angoche
# Processing Record 27 of Set 5 | okhotsk
# Processing Record 28 of Set 5 | dabakala
# Processing Record 29 of Set 5 | beboto
# Processing Record 30 of Set 5 | suratgarh
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | xichang
# Processing Record 33 of Set 5 | neiafu
# Processing Record 34 of Set 5 | mayuge
# Processing Record 35 of Set 5 | dabra
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | kloulklubed
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | tiksi
# Processing Record 41 of Set 5 | uravakonda
# Processing Record 42 of Set 5 | bintulu
# Processing Record 43 of Set 5 | pangnirtung
# Processing Record 44 of Set 5 | simplicio mendes
# Processing Record 45 of Set 5 | damietta
# Processing Record 46 of Set 5 | bilibino
# Processing Record 47 of Set 5 | khandyga
# Processing Record 48 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 5 | nizhniy ingash
# Processing Record 0 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 6 | east london
# Processing Record 2 of Set 6 | kirensk
# Processing Record 3 of Set 6 | caceres
# Processing Record 4 of Set 6 | cambyreta
# City not found. Skipping...
# Processing Record 5 of Set 6 | sala consilina
# Processing Record 6 of Set 6 | catamarca
# City not found. Skipping...
# Processing Record 7 of Set 6 | marrakesh
# Processing Record 8 of Set 6 | kamenka
# Processing Record 9 of Set 6 | camacha
# Processing Record 10 of Set 6 | myshkin
# Processing Record 11 of Set 6 | meliti
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | kodinsk
# Processing Record 14 of Set 6 | araouane
# Processing Record 15 of Set 6 | iqaluit
# Processing Record 16 of Set 6 | roald
# Processing Record 17 of Set 6 | vanavara
# Processing Record 18 of Set 6 | coari
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | evensk
# Processing Record 21 of Set 6 | kieta
# Processing Record 22 of Set 6 | necochea
# Processing Record 23 of Set 6 | mosquera
# Processing Record 24 of Set 6 | menongue
# Processing Record 25 of Set 6 | tukrah
# City not found. Skipping...
# Processing Record 26 of Set 6 | raudeberg
# Processing Record 27 of Set 6 | peniche
# Processing Record 28 of Set 6 | warrington
# Processing Record 29 of Set 6 | beauvais
# Processing Record 30 of Set 6 | calatayud
# Processing Record 31 of Set 6 | pacific grove
# Processing Record 32 of Set 6 | lasa
# Processing Record 33 of Set 6 | kedrovyy
# Processing Record 34 of Set 6 | karratha
# Processing Record 35 of Set 6 | aravankadu
# Processing Record 36 of Set 6 | hami
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | nabire
# Processing Record 39 of Set 6 | grande-riviere
# City not found. Skipping...
# Processing Record 40 of Set 6 | bowen
# Processing Record 41 of Set 6 | katobu
# Processing Record 42 of Set 6 | churhat
# Processing Record 43 of Set 6 | ulukulevo
# Processing Record 44 of Set 6 | vanimo
# Processing Record 45 of Set 6 | dingle
# Processing Record 46 of Set 6 | ninghai
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | shubarshi
# Processing Record 49 of Set 6 | zhigansk
# Processing Record 0 of Set 7 | alice springs
# Processing Record 1 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 7 | lovozero
# Processing Record 3 of Set 7 | balkanabat
# Processing Record 4 of Set 7 | madison
# Processing Record 5 of Set 7 | sola
# Processing Record 6 of Set 7 | dondo
# Processing Record 7 of Set 7 | gamba
# Processing Record 8 of Set 7 | sile
# Processing Record 9 of Set 7 | kyra
# City not found. Skipping...
# Processing Record 10 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 7 | eyrarbakki
# Processing Record 12 of Set 7 | yumen
# Processing Record 13 of Set 7 | egvekinot
# Processing Record 14 of Set 7 | naze
# Processing Record 15 of Set 7 | winnemucca
# Processing Record 16 of Set 7 | conceicao do araguaia
# Processing Record 17 of Set 7 | cidreira
# Processing Record 18 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 19 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 7 | ancud
# Processing Record 21 of Set 7 | ayan
# Processing Record 22 of Set 7 | itoman
# Processing Record 23 of Set 7 | aneho
# Processing Record 24 of Set 7 | bani
# Processing Record 25 of Set 7 | richards bay
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | uyskoye
# Processing Record 28 of Set 7 | boma
# Processing Record 29 of Set 7 | broken hill
# Processing Record 30 of Set 7 | suez
# Processing Record 31 of Set 7 | praia
# Processing Record 32 of Set 7 | aksarka
# Processing Record 33 of Set 7 | souillac
# Processing Record 34 of Set 7 | chara
# Processing Record 35 of Set 7 | la ronge
# Processing Record 36 of Set 7 | bredasdorp
# Processing Record 37 of Set 7 | prince rupert
# Processing Record 38 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 7 | bethel
# Processing Record 40 of Set 7 | yabrud
# Processing Record 41 of Set 7 | pontal do parana
# Processing Record 42 of Set 7 | grand gaube
# Processing Record 43 of Set 7 | imeni poliny osipenko
# Processing Record 44 of Set 7 | pamanukan
# Processing Record 45 of Set 7 | mantua
# Processing Record 46 of Set 7 | lermontovka
# Processing Record 47 of Set 7 | tual
# Processing Record 48 of Set 7 | saint-georges
# Processing Record 49 of Set 7 | brae
# Processing Record 0 of Set 8 | qaqortoq
# Processing Record 1 of Set 8 | deyang
# Processing Record 2 of Set 8 | kamaishi
# Processing Record 3 of Set 8 | boras
# Processing Record 4 of Set 8 | kaduy
# Processing Record 5 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 8 | samarai
# Processing Record 7 of Set 8 | hervey bay
# Processing Record 8 of Set 8 | carndonagh
# Processing Record 9 of Set 8 | igarka
# Processing Record 10 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 8 | santa cruz de la palma
# Processing Record 12 of Set 8 | paulo ramos
# Processing Record 13 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | gizo
# Processing Record 16 of Set 8 | entre rios
# Processing Record 17 of Set 8 | zarubino
# Processing Record 18 of Set 8 | varzea da palma
# Processing Record 19 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | da lat
# Processing Record 23 of Set 8 | pyaozerskiy
# Processing Record 24 of Set 8 | sibolga
# Processing Record 25 of Set 8 | iberia
# Processing Record 26 of Set 8 | vila velha
# Processing Record 27 of Set 8 | muros
# Processing Record 28 of Set 8 | ketchikan
# Processing Record 29 of Set 8 | padre bernardo
# City not found. Skipping...
# Processing Record 30 of Set 8 | tefe
# Processing Record 31 of Set 8 | snyder
# Processing Record 32 of Set 8 | yanam
# Processing Record 33 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 8 | bonthe
# Processing Record 35 of Set 8 | weligama
# Processing Record 36 of Set 8 | great yarmouth
# Processing Record 37 of Set 8 | batken
# Processing Record 38 of Set 8 | san ignacio
# Processing Record 39 of Set 8 | paamiut
# Processing Record 40 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 8 | mandera
# Processing Record 42 of Set 8 | karlstad
# Processing Record 43 of Set 8 | lang son
# Processing Record 44 of Set 8 | alofi
# Processing Record 45 of Set 8 | anadyr
# Processing Record 46 of Set 8 | salalah
# Processing Record 47 of Set 8 | slave lake
# Processing Record 48 of Set 8 | isangel
# Processing Record 49 of Set 8 | guiuan
# Processing Record 0 of Set 9 | korem
# Processing Record 1 of Set 9 | vila franca do campo
# Processing Record 2 of Set 9 | manitouwadge
# Processing Record 3 of Set 9 | zatoka
# Processing Record 4 of Set 9 | zhezkazgan
# Processing Record 5 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 9 | nome
# Processing Record 7 of Set 9 | atsiki
# City not found. Skipping...
# Processing Record 8 of Set 9 | port-cartier
# Processing Record 9 of Set 9 | gallup
# Processing Record 10 of Set 9 | buin
# Processing Record 11 of Set 9 | severnyy
# City not found. Skipping...
# Processing Record 12 of Set 9 | faanui
# Processing Record 13 of Set 9 | manavalakurichi
# Processing Record 14 of Set 9 | minot
# Processing Record 15 of Set 9 | vao
# Processing Record 16 of Set 9 | sovetskiy
# Processing Record 17 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 9 | san andres
# Processing Record 19 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 9 | tessalit
# Processing Record 21 of Set 9 | pasuquin
# Processing Record 22 of Set 9 | killybegs
# Processing Record 23 of Set 9 | isagarh
# Processing Record 24 of Set 9 | baglan
# Processing Record 25 of Set 9 | hauterive
# Processing Record 26 of Set 9 | constantine
# Processing Record 27 of Set 9 | yarada
# Processing Record 28 of Set 9 | townsville
# Processing Record 29 of Set 9 | cervo
# Processing Record 30 of Set 9 | flagstaff
# Processing Record 31 of Set 9 | zeya
# Processing Record 32 of Set 9 | okha
# Processing Record 33 of Set 9 | dzhebariki-khaya
# Processing Record 34 of Set 9 | waiouru
# Processing Record 35 of Set 9 | senanga
# Processing Record 36 of Set 9 | inhambane
# Processing Record 37 of Set 9 | malkapur
# Processing Record 38 of Set 9 | takoradi
# Processing Record 39 of Set 9 | yavaros
# Processing Record 40 of Set 9 | uvinza
# Processing Record 41 of Set 9 | belle fourche
# Processing Record 42 of Set 9 | yatou
# Processing Record 43 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 9 | ust-maya
# Processing Record 45 of Set 9 | wonthaggi
# Processing Record 46 of Set 9 | hambantota
# Processing Record 47 of Set 9 | coahuayana
# Processing Record 48 of Set 9 | parkes
# Processing Record 49 of Set 9 | geraldton
# Processing Record 0 of Set 10 | cape coast
# Processing Record 1 of Set 10 | mayo
# Processing Record 2 of Set 10 | keti bandar
# Processing Record 3 of Set 10 | prainha
# Processing Record 4 of Set 10 | svetlyy
# City not found. Skipping...
# Processing Record 5 of Set 10 | bandarbeyla
# Processing Record 6 of Set 10 | miranda
# Processing Record 7 of Set 10 | glenwood springs
# Processing Record 8 of Set 10 | kapit
# Processing Record 9 of Set 10 | mehamn
# Processing Record 10 of Set 10 | roma
# Processing Record 11 of Set 10 | berbera
# City not found. Skipping...
# Processing Record 12 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 10 | sabang
# Processing Record 14 of Set 10 | caravelas
# Processing Record 15 of Set 10 | durham
# Processing Record 16 of Set 10 | portland
# Processing Record 17 of Set 10 | meulaboh
# Processing Record 18 of Set 10 | rawson
# Processing Record 19 of Set 10 | aksu
# Processing Record 20 of Set 10 | wagar
# Processing Record 21 of Set 10 | sokoni
# Processing Record 22 of Set 10 | fougamou
# Processing Record 23 of Set 10 | port shepstone
# Processing Record 24 of Set 10 | danielskuil
# Processing Record 25 of Set 10 | mezen
# Processing Record 26 of Set 10 | bousso
# City not found. Skipping...
# Processing Record 27 of Set 10 | touros
# Processing Record 28 of Set 10 | adrar
# Processing Record 29 of Set 10 | ambon
# Processing Record 30 of Set 10 | bontang
# Processing Record 31 of Set 10 | duz
# City not found. Skipping...
# Processing Record 32 of Set 10 | juneau
# Processing Record 33 of Set 10 | amberley
# Processing Record 34 of Set 10 | tara
# Processing Record 35 of Set 10 | lakatoro
# Processing Record 36 of Set 10 | vitoria da conquista
# City not found. Skipping...
# Processing Record 37 of Set 10 | lamar
# Processing Record 38 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 10 | oum hadjer
# Processing Record 40 of Set 10 | fortuna
# Processing Record 41 of Set 10 | lajas
# Processing Record 42 of Set 10 | ishigaki
# Processing Record 43 of Set 10 | lakes entrance
# Processing Record 44 of Set 10 | dunkwa
# Processing Record 45 of Set 10 | copperas cove
# Processing Record 46 of Set 10 | kautokeino
# Processing Record 47 of Set 10 | benemerito de las americas
# Processing Record 48 of Set 10 | chimbote
# Processing Record 49 of Set 10 | vestmannaeyjar
# Processing Record 0 of Set 11 | tezu
# Processing Record 1 of Set 11 | kambove
# Processing Record 2 of Set 11 | kropotkin
# Processing Record 3 of Set 11 | greenwood
# Processing Record 4 of Set 11 | mikhaylovka
# Processing Record 5 of Set 11 | la asuncion
# Processing Record 6 of Set 11 | san policarpo
# Processing Record 7 of Set 11 | launceston
# Processing Record 8 of Set 11 | smithers
# Processing Record 9 of Set 11 | nurota
# Processing Record 10 of Set 11 | priiskovyy
# Processing Record 11 of Set 11 | salamiyah
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | tautira
# Processing Record 14 of Set 11 | olga
# Processing Record 15 of Set 11 | westport
# Processing Record 16 of Set 11 | mwinilunga
# Processing Record 17 of Set 11 | kokopo
# Processing Record 18 of Set 11 | mugur-aksy
# Processing Record 19 of Set 11 | aktau
# Processing Record 20 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 11 | mallama
# City not found. Skipping...
# Processing Record 22 of Set 11 | harper
# Processing Record 23 of Set 11 | nena
# Processing Record 24 of Set 11 | monrovia
# Processing Record 25 of Set 11 | gotsu
# Processing Record 26 of Set 11 | impfondo
# Processing Record 27 of Set 11 | luau
# Processing Record 28 of Set 11 | skovde
# City not found. Skipping...
# Processing Record 29 of Set 11 | privolzhskiy
# Processing Record 30 of Set 11 | oltu
# Processing Record 31 of Set 11 | cachoeiras de macacu
# Processing Record 32 of Set 11 | taoudenni
# Processing Record 33 of Set 11 | pipirig
# Processing Record 34 of Set 11 | marang
# City not found. Skipping...
# Processing Record 35 of Set 11 | verkhnyaya inta
# Processing Record 36 of Set 11 | altamira
# Processing Record 37 of Set 11 | joshimath
# Processing Record 38 of Set 11 | holalkere
# Processing Record 39 of Set 11 | mocuba
# Processing Record 40 of Set 11 | khvoynaya
# Processing Record 41 of Set 11 | sorland
# Processing Record 42 of Set 11 | oriximina
# Processing Record 43 of Set 11 | comodoro rivadavia
# Processing Record 44 of Set 11 | natal
# Processing Record 45 of Set 11 | asfi
# City not found. Skipping...
# Processing Record 46 of Set 11 | nguru
# Processing Record 47 of Set 11 | marawi
# Processing Record 48 of Set 11 | katsuura
# Processing Record 49 of Set 11 | dillon
# Processing Record 0 of Set 12 | port blair
# Processing Record 1 of Set 12 | kutum
# Processing Record 2 of Set 12 | harqalah
# Processing Record 3 of Set 12 | kupang
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | zenzeli
# Processing Record 6 of Set 12 | murgab
# Processing Record 7 of Set 12 | lanzhou
# Processing Record 8 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 12 | miles city
# Processing Record 10 of Set 12 | nelson bay
# Processing Record 11 of Set 12 | bull savanna
# Processing Record 12 of Set 12 | leh
# Processing Record 13 of Set 12 | qiqihar
# Processing Record 14 of Set 12 | quetta
# Processing Record 15 of Set 12 | hinton
# Processing Record 16 of Set 12 | umm kaddadah
# Processing Record 17 of Set 12 | imbituba
# Processing Record 18 of Set 12 | paysandu
# Processing Record 19 of Set 12 | santa cruz
# Processing Record 20 of Set 12 | mackay
# Processing Record 21 of Set 12 | taveta
# Processing Record 22 of Set 12 | ibra
# Processing Record 23 of Set 12 | pangody
# Processing Record 24 of Set 12 | olafsvik
# City not found. Skipping...
# Processing Record 25 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 12 | sur
# Processing Record 27 of Set 12 | atherton
# Processing Record 28 of Set 12 | ovalle
# Processing Record 29 of Set 12 | betare oya
# Processing Record 30 of Set 12 | kashi
# City not found. Skipping...
# Processing Record 31 of Set 12 | bac lieu
# City not found. Skipping...
# Processing Record 32 of Set 12 | fenyi
# Processing Record 33 of Set 12 | koumac
# Processing Record 34 of Set 12 | adeje
# Processing Record 35 of Set 12 | genhe
# Processing Record 36 of Set 12 | bima
# Processing Record 37 of Set 12 | atbasar
# Processing Record 38 of Set 12 | luba
# Processing Record 39 of Set 12 | kortkeros
# Processing Record 40 of Set 12 | teupasenti
# Processing Record 41 of Set 12 | san jose
# Processing Record 42 of Set 12 | chincholi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#create a data frame
citi_samples = pd.DataFrame(city_data)

#display count of weather data values
citi_samples.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        aykhal          90      RU  1571364811       100  65.95  111.51
# 1     carnarvon         100      ZA  1571364811        47 -30.97   22.13
# 2      victoria          75      BN  1571364812        74   5.28  115.24
# 3     busselton          53      AU  1571364812        34 -33.64  115.35
# 4  norman wells          90      CA  1571364812        95  65.28 -126.83
#
#    Max Temp  Wind Speed
# 0     30.20        8.95
# 1     68.51        6.67
# 2     86.00        5.82
# 3     66.99        8.10
# 4     32.00        5.82

# %%
citi_samples.to_csv('citi_samples.csv')

# %% [markdown]
# # latitude vs Temperature

# %%
plt.scatter(citi_samples['Lat'], citi_samples['Max Temp'], marker="o", s=10)
plt.title(f"City Latitude vs. Max Temp")
plt.xlabel("Lat")
plt.ylabel("Max Temp")
plt.savefig("Max_Temp.png")
plt.show()

# %% [markdown]
# # Latitude vs Humidity

# %%
plt.scatter(citi_samples['Lat'], citi_samples['Humidity'])
plt.title(f"Humidity (%) vs. Lat")
plt.xlabel("Lat")
plt.ylabel("Humidity (%)")
plt.style.use('ggplot')
plt.savefig("Humidity.png")
plt.show()

# %% [markdown]
# # Latitude vs Cloudy

# %%
plt.scatter(citi_samples['Lat'], citi_samples['Cloudiness'])
plt.title(f"Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Cloudiness.png")
plt.show()

# %% [markdown]
# # Latitude vs Windspeed

# %%
plt.scatter(citi_samples['Lat'], citi_samples['Wind Speed'])
plt.title(f"Wind Speed(mph) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.style.use('ggplot')
plt.savefig("Wind_Speed.png")
plt.show()

# %% [markdown]
# # Observable Trends / Analysis

# %% [markdown]
# 1. I believe there is a relatively strong correlation bewteen latitude and temperature. We can observe that cities near the equator did not experience the highest temperatures, however, high temperatures were more consistent in that area and temperatures are higher the closer to 0 latitude. In this case,  phenomenon may be related to differences in the number of cities that fall along these latitudes as well as the geographic features. To be accurate, concluding that the highest temperatures were observed between latitudes of 20 and 35 degrees and using the average temperature parameter, we can see more consistency of high temperature between -20 and 20 degrees latitude.
#
# 2. The correlation between humidity and latitude is weak, humidity is more concentrated at higher values as the latitude approaches the latitude 0 and the cities on the equator experienced most of the latitudes have humidity ranging from 40% to 100%.
#
# 3. As we can see from the graph, the correlation between latitude and wind speed is very weak. As wind speeds increase the latitude drives away from the equator. The most frequent observation was speeds between 0 and 10 mph. Observations decrease in frequency as you increase wind speed with wind speeds greater than 30 mph. Utilizig plotting latitude versus longitude, we can further observe addition patterns in weather by location as well. Local patterns are observed by geographic regions -- wind speed appear to be generally higher closer to coastal regions.
#
# 4. No significant correlation was found between latitude and cloudiness.
